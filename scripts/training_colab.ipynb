# %%
# !rm -rf sample_data
# !git clone https://github.com/thomas0barand/robust-deepfake-detector.git
# !cd robust-deepfake-detector/ && git switch THOMAS/sonics
# !cd robust-deepfake-detector/ && ls
# !mv robust-deepfake-detector/* .
# !rm -rf robust-deepfake-detector
# Out:
# Cloning into 'robust-deepfake-detector'...
# remote: Enumerating objects: 1569, done.
# remote: Counting objects: 100% (269/269), done.
# remote: Compressing objects: 100% (186/186), done.
# remote: Total 1569 (delta 112), reused 180 (delta 79), pack-reused 1300 (from 2)
# Receiving objects: 100% (1569/1569), 1.24 GiB | 23.34 MiB/s, done.
# Resolving deltas: 100% (619/619), done.
# Updating files: 100% (102/102), done.
# Branch 'THOMAS/sonics' set up to track remote branch 'THOMAS/sonics' from 'origin'.
# Switched to a new branch 'THOMAS/sonics'
# checkpoints  pyproject.toml  requirements.lock	scripts
# data	     README.md	     research		src

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf data/sonics/*

# %%
import os

attack_modes = ["attack"]
splits = ["train","valid"]
gen_models = [ "udio_v120", "human"]

for split in splits:
  for gen_model in gen_models:
    for attack_mode in attack_modes:
      # Create the target directory locally, creating parent directories if they don't exist
      target_dir = f"data/sonics/{attack_mode}/{split}/{gen_model}"
      os.makedirs(target_dir, exist_ok=True)

      # Source directory in Google Drive, dynamically constructed based on loop variables
      source_dir_in_drive = f"/content/drive/MyDrive/robust-deepfake-detector/data/sonics/{attack_mode}/{split}/{gen_model}"
      # !cp -r {source_dir_in_drive}/* {target_dir}/

# %%
# !pip install lightning nnAudio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 60.3 MB/s eta 0:00:00
# ...

# %%
# !python -m scripts.train \
  --data_dir /content/data/sonics/attack \
  --gen_model udio_v120 \
  --ckpt_dir checkpoints/attack/udio_v120 \
  --mode stft \
  --log_stft \
  --use_norm \
  --use_convolution \
  --use_bias \
  --freq_range 500 5000 \
  --sampling_rate 16000 \
  --n_fft 16384 \
  --bins_per_octave_stft 1920 \
  --hull_area 20 \
  --fmin 32.7 \
  --lr 0.001 \
  --lamb 0.1 \
  --weight_decay 1e-5 \
  --max_epochs 50 \
  --patience 5 \
  --num_workers 2 \
  --batch_size 64 \
  --seed 42
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#                                                                0.984
# Validation  ━━━━━━━━╺━━━━━━━ 35/69   0:00:00 •       46.42it/s
# Epoch 29/49 ━━━━━━━━━━━━━━━━ 575/575 0:00:20 •       28.10it/s v_num: 1.000
#                                      0:00:00                   val_loss: 0.209
#                                                                val_auroc: 0.997
#                                                                val_f1: 0.981
#                                                                val_precision:
#                                                                0.983
#                                                                val_accuracy:
#                                                                0.984
# Validation  ━━━━━━━━╺━━━━━━━ 36/69   0:00:00 •       46.73it/s
# Epoch 29/49 ━━━━━━━━━━━━━━━━ 575/575 0:00:20 •       28.10it/s v_num: 1.000
# ...
